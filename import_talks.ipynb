# %%
from pubman_manager import PubmanCreator, TALKS_DIR

api = PubmanCreator()

api.create_talks(TALKS_DIR / 'new' / 'Raabe_talks.xlsx', create_items = True, submit_items=True, overwrite=True)
# Out:
# C:\Users\d.mentock\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# C:\Users\d.mentock\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# INFO:root:Generating requests for "The Basic Science of Green Steel"
# INFO:root:Generating requests for "Transport and phase transformations phenomena in sustainable hydrogen-based steel production"
# INFO:root:Generating requests for "Atomic-Scale Perspective at Alloy-Design for Additive Manufacturing"
# INFO:root:Generating requests for "The Two Billion Tonnes Question: How Can Research Help to Make Metals Sustainable?"
# ...
