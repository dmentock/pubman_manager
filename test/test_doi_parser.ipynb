# %%
from pubman_manager import DOIParser, PubmanBase, PUBLICATIONS_DOIS_DIR
import os
from dotenv import load_dotenv

load_dotenv()
scopus_api_key = os.getenv("SCOPUS_API_KEY")
username = os.getenv("USERNAME")
password = os.getenv("PASSWORD")
pubman_api = PubmanBase(username, password)

doi_parser = DOIParser(scopus_api_key, pubman_api)
names_affiliations = [
    'Leonardo Shoji Aota',
    'Taylor Swift',
    'Bob Marley',
    'John Michael Smith',
    'John Smith',
    'Thoudden Sukumar Prithiv',
    'Renelle Dubosq',
    'Christian Liebscher',
    'Christian H. Liebscher',
    'B. Zhou',
    'Xuyang Zhou',
    'T. Schwarz',
    'Tim Schwarz',
    'Jing Yang',
    'Zhigang Yang',
    'Matic Jovičević-Klug',
    'Hyoung Seop Kim',
    'Se-Ho Kim',
    'Bao Wang',
    'B. Wang',
    'Hoa Wang',
    'Byoungchul Hwang'
]

test_names = [
    'Leonardo S. Aota',
    'L. S. Aota',
    'L. Aota',
    'J. M. Smith',
    'J. Smith',
    'T. Swift',
    'B. Marley',
    'Bob John Marley',
    'Bob J. Marley',
    'T.S. Prithiv',
    'R. Dubosq',
    'Christian H. Liebscher',
    'Xuyang Zhou',
    'Tim M. Schwarz',
    'Jing Yang',
    'Matic Jovicevic-Klug',
    'Se Ho Kim',
    'Hao Wang'
]

matched_names = {abbreviated_name: doi_parser.process_name(names_affiliations, abbreviated_name) for abbreviated_name in test_names}


matched_names
# Out:
# C:\Users\d.mentock\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# process_name Leonardo S. Aota
# full_name
# first_name leonardo
# full_name Leonardo Shoji Aota
# first_name[0] == full_name_parts[0][0] True
# first_name==full_name_parts[0] True
# score1 1
# score2 2
# nonon Leonardo Shoji Aota
# nonon2 Leonardo Shoji Aota
# process_name L. S. Aota
# full_name
# first_name l.
# full_name Leonardo Shoji Aota
# first_name[0] == full_name_parts[0][0] True
# first_name==full_name_parts[0] False
# score1 2
# score2 4
# nonon Leonardo Shoji Aota
# nonon2 Leonardo Shoji Aota
# process_name L. Aota
# full_name
# first_name l.
# full_name Leonardo Shoji Aota
# first_name[0] == full_name_parts[0][0] True
# first_name==full_name_parts[0] False
# score1 1
# score2 2
# nonon Leonardo Shoji Aota
# nonon2 Leonardo Shoji Aota
# process_name J. M. Smith
# full_name
# first_name j.
# full_name John Michael Smith
# first_name[0] == full_name_parts[0][0] True
# first_name==full_name_parts[0] False
# score1 2
# score2 4
# first_name j.
# full_name John Smith
# first_name[0] == full_name_parts[0][0] True
# first_name==full_name_parts[0] False
# score1 1
# score2 1
# nonon John Michael Smith
# nonon2 John Michael Smith
# process_name J. Smith
# full_name
# first_name j.
# full_name John Michael Smith
# first_name[0] == full_name_parts[0][0] True
# first_name==full_name_parts[0] False
# score1 1
# score2 2
# first_name j.
# full_name John Smith
# first_name[0] == full_name_parts[0][0] True
# first_name==full_name_parts[0] False
# score1 1
# score2 2
# nonon John Michael Smith
# nonon2 John Michael Smith
# process_name T. Swift
# full_name
# first_name t.
# full_name Taylor Swift
# first_name[0] == full_name_parts[0][0] True
# first_name==full_name_parts[0] False
# score1 1
# score2 2
# nonon Taylor Swift
# nonon2 Taylor Swift
# process_name B. Marley
# full_name
# first_name b.
# full_name Bob Marley
# first_name[0] == full_name_parts[0][0] True
# first_name==full_name_parts[0] False
# score1 1
# score2 2
# nonon Bob Marley
# nonon2 Bob Marley
# process_name Bob John Marley
# full_name
# first_name bob
# full_name Bob Marley
# first_name[0] == full_name_parts[0][0] True
# first_name==full_name_parts[0] True
# score1 0
# score2 0
# nonon Bob Marley
# nonon2 Bob Marley
# process_name Bob J. Marley
# full_name
# first_name bob
# full_name Bob Marley
# first_name[0] == full_name_parts[0][0] True
# first_name==full_name_parts[0] True
# score1 0
# score2 0
# nonon Bob Marley
# nonon2 Bob Marley
# process_name T.S. Prithiv
# full_name
# first_name t.s.
# full_name Thoudden Sukumar Prithiv
# first_name[0] == full_name_parts[0][0] True
# first_name==full_name_parts[0] False
# score1 1
# score2 2
# nonon Thoudden Sukumar Prithiv
# nonon2 Thoudden Sukumar Prithiv
# process_name R. Dubosq
# full_name
# first_name r.
# full_name Renelle Dubosq
# first_name[0] == full_name_parts[0][0] True
# first_name==full_name_parts[0] False
# score1 1
# score2 2
# nonon Renelle Dubosq
# nonon2 Renelle Dubosq
# process_name Christian H. Liebscher
# full_name
# process_name Xuyang Zhou
# process_name Tim M. Schwarz
# full_name
# first_name tim
# full_name Tim Schwarz
# first_name[0] == full_name_parts[0][0] True
# first_name==full_name_parts[0] True
# score1 0
# score2 0
# nonon Tim Schwarz
# nonon2 Tim Schwarz
# process_name Jing Yang
# process_name Matic Jovicevic-Klug
# process_name Se Ho Kim
# full_name
# process_name Hao Wang
# full_name
# nonon None
# nonon2 None
# nonon3
# {'Leonardo S. Aota': 'Leonardo Shoji Aota',
#  'L. S. Aota': 'Leonardo Shoji Aota',
#  'L. Aota': 'Leonardo Shoji Aota',
#  'J. M. Smith': 'John Michael Smith',
#  'J. Smith': 'John Michael Smith',
#  'T. Swift': 'Taylor Swift',
#  'B. Marley': 'Bob Marley',
#  'Bob John Marley': 'Bob Marley',
#  'Bob J. Marley': 'Bob Marley',
#  'T.S. Prithiv': 'Thoudden Sukumar Prithiv',
#  'R. Dubosq': 'Renelle Dubosq',
#  'Christian H. Liebscher': 'Christian H. Liebscher',
#  'Xuyang Zhou': 'Xuyang Zhou',
#  'Tim M. Schwarz': 'Tim Schwarz',
#  'Jing Yang': 'Jing Yang',
#  'Matic Jovicevic-Klug': 'Matic Jovičević-Klug',
#  'Se Ho Kim': 'Se-Ho Kim',
#  'Hao Wang': 'Hao Wang'}

# %%
from pubman_manager import DOIParser, PubmanBase, PUBLICATIONS_DOIS_DIR
import os
from dotenv import load_dotenv

load_dotenv()
scopus_api_key = os.getenv("SCOPUS_API_KEY")
username = os.getenv("USERNAME")
password = os.getenv("PASSWORD")
pubman_api = PubmanBase(username, password)

doi_parser = DOIParser(scopus_api_key, pubman_api)
dois = [
        # '10.1016/j.ijplas.2022.103405',
        '10.1016/j.matdes.2022.110503',
        # '10.1007/s11661-023-06959-4',
        # '10.1016/j.mtla.2022.101625',
        # '10.1016/j.ijrmhm.2023.106124'
        ]

a = doi_parser.download_scopus_pdf(dois[0])
# dois_data = doi_parser.collect_data_for_dois(dois)
# dois_data


# doi_parser.iterate_over_sheets_in_folder(PUBLICATIONS_DOIS_DIR)
# dois_data = doi_parser.collect_data_for_doi('10.1002/advs.202300626')
# doi_parser.process_author_list({'Se-Ho Kim': ['MPIE']}, '')
# Out:
# C:\Users\d.mentock\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# DOI: 10.1016/j.matdes.2022.110503

# %%
doi_parser.write_dois_data(dois_data, 'test_dois.xlsx')
# Out:
# publication_color, pink
# compare_errorcompare_error 0.07
# publication_color, gray
# compare_errorcompare_error
# publication_color, pink
# compare_errorcompare_error 0.07
# publication_color, gray
# compare_errorcompare_error
# publication_color, gray
# compare_errorcompare_error 0.5
# publication_color, gray
# compare_errorcompare_error
# publication_color, pink
# compare_errorcompare_error 0.07
# publication_color, orange
# compare_errorcompare_error 0.14
# publication_color, pink
# compare_errorcompare_error 0.07
# publication_color, yellow
# compare_errorcompare_error 0.18
# publication_color, yellow
# compare_errorcompare_error 0.07
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# publication_color, None
# Saved test_dois.xlsx successfully.
