# %% [markdown]
# Test process_names

# %%
from pubman_manager import DOIParser, PubmanBase, PUBLICATIONS_DOIS_DIR
import os
import unicodedata

pubman_api = PubmanBase()

doi_parser = DOIParser(pubman_api)


names_affiliations = [
    ('Leonardo Shoji','Aota'),
    ('Taylor','Swift'),
    ('Bob','Marley'),
    ('John Michael','Smith'),
    ('John','Smith'),
    ('Thoudden Sukumar','Prithiv'),
    ('Renelle','Dubosq'),
    ('Christian','Liebscher'),
    ('Christian H.','Liebscher'),
    ('B.','Zhou'),
    ('Xuyang','Zhou'),
    ('T.','Schwarz'),
    ('Tim','Schwarz'),
    ('Jing','Yang'),
    ('Zhigang','Yang'),
    ('Matic','Jovičević-Klug'),
    ('Hyoung Seop','Kim'),
    ('Se-Ho','Kim'),
    ('Bao','Wang'),
    ('B.','Wang'),
    ('Hoa','Wang'),
    ('Byoungchul','Hwang'),
    ('H.','Wang'),
    ('Seok-Hyeon','Kang'),
    ('Sung Gyu','Kang'),
    ('Leigh','Stephenson'),
    ('Leigh T.','Stephenson'),
    ('Abhishek Kumar','Singh'),
    ('Mahander Pratap','Singh'),
    ('Xipeng','Xu'),
    ('Dierk','Raabe'),
    ('Sang Jun','Kim'),
    ('Hans', 'Chen'),
    ('Hao', 'Chen'),
      ]

test_names = [
    ('Leonardo S.','Aota'),
    # ('L. S.','Aota'),
    # ('L.','Aota'),
    # ('J. M.','Smith'),
    # ('J.','Smith'),
    # ('T.','Swift'),
    # ('B.','Marley'),
    ('Bob John','Marley'),
    ('Bob J.','Marley'),
    # ('T.S.','Prithiv'),
    # ('R.','Dubosq'),
    ('Christian H.','Liebscher'),
    ('Xuyang','Zhou'),
    ('Tim M.','Schwarz'),
    ('Jing','Yang'),
    ('Matic','Jovicevic-Klug'),
    ('Se Ho','Kim'),
    ('Hao','Wang'),
    ('Sung-Gyu','Kang'),
    ('Sung','Kang'),
    # ('L. T.','Stephenson'),
    # ('M.P.','Singh'),
    ('Johanna','Xu'),
    # ('A. J.','Knowles'),
    ('Dierk','Raabe'),
    ('SeHo','Kim'),
    ('Haoxiu', 'Chen'),
    ('Jürgen', 'Schön')
]

# matched_names = {abbreviated_name: compare_author_name_to_pure_db(names_affiliations, abbreviated_name) for abbreviated_name in test_names}
matched_names = {(first_name, last_name): doi_parser.compare_author_name_to_pure_db(names_affiliations, first_name, last_name) for first_name, last_name in test_names}


matched_names
# Out:
# INFO:root:No auth_token provided, using ENV_USERNAME and ENV_PASSWORD
# ...

# %% [markdown]
# Test full name fetching from scopus

# %%
from pubman_manager import DOIParser, PubmanBase, PUBLICATIONS_DOIS_DIR

pubman_api = PubmanBase()
doi_parser = DOIParser(pubman_api)

doi_parser.get_scopus_author_full_name('56446050300')
# Out:
# C:\Users\d.mentock\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# 'Mahander Pratap Singh'

# %% [markdown]
# Test collect_data_for_dois

# %%
from pubman_manager import DOIParser, PubmanBase, PUBLICATIONS_DOIS_DIR
import os

pubman_api = PubmanBase()
doi_parser = DOIParser(pubman_api)

doi = '10.1016/j.actamat.2024.120229'
crossref_metadata = doi_parser.get_crossref_metadata(doi)
crossref_metadata
# scopus_metadata = doi_parser.get_scopus_metadata(doi, doi_parser.scopus_api_key)
# author_affiliaton_map = doi_parser.extract_scopus_authors_affiliations(scopus_metadata)
# parsed_data = doi_parser.collect_data_for_dois([doi])
# Out:
# {'indexed': {'date-parts': [[2024, 8, 31]],
#   'date-time': '2024-08-31T00:17:50Z',
#   'timestamp': 1725063470659},
#  'reference-count': 107,
#  'publisher': 'Elsevier BV',
#  'license': [{'start': {'date-parts': [[2024, 10, 1]],
#     'date-time': '2024-10-01T00:00:00Z',
#     'timestamp': 1727740800000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/tdm/userlicense/1.0/'},
#   {'start': {'date-parts': [[2024, 10, 1]],
#     'date-time': '2024-10-01T00:00:00Z',
#     'timestamp': 1727740800000},
#    'content-version': 'tdm',
#    'delay-in-days': 0,
#    'URL': 'https://www.elsevier.com/legal/tdmrep-license'},
#   {'start': {'date-parts': [[2024, 7, 27]],
#     'date-time': '2024-07-27T00:00:00Z',
#     'timestamp': 1722038400000},
#    'content-version': 'vor',
#    'delay-in-days': 0,
#    'URL': 'http://creativecommons.org/licenses/by/4.0/'}],
#  'funder': [{'DOI': '10.13039/501100001665',
#    'name': 'ANR',
# ...

# %% [markdown]
# Test extract_scopus_authors_affiliations

# %%
from pubman_manager import DOIParser, PubmanBase, PUBLICATIONS_DOIS_DIR
pubman_api = PubmanBase()
doi_parser = DOIParser(pubman_api)

doi = '10.1016/j.scriptamat.2021.114308'
scopus_metadata = doi_parser.get_scopus_metadata(doi)
author_affiliaton_map = doi_parser.extract_scopus_authors_affiliations(scopus_metadata)
# parsed_data = doi_parser.collect_data_for_dois([doi])
author_affiliaton_map
# Out:
# C:\Users\d.mentock\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# preferred_name.get('given-name', '') Eric A.
# preferred_name.get('surname', '') Jägle
# OrderedDict([(('Dong-Hyun', 'Lee'),
#               ['Department of Materials Science and Engineering, Chungnam National University, 34134 Daejeon, Republic of Korea']),
#              (('Yakai', 'Zhao'),
#               ['School of Mechanical and Aerospace Engineering, Nanyang Technological University, 639798 Singapore']),
#              (('Soo', 'Lee'),
#               ['Department of Materials Science and Engineering, Chungnam National University, 34134 Daejeon, Republic of Korea']),
#              (('Dirk', 'Ponge'),
# ...

# %% [markdown]
# Test download_pdf

# %%
from pubman_manager import DOIParser, PubmanBase, PUBLICATIONS_DOIS_DIR
import os

pubman_api = PubmanBase()
doi_parser = DOIParser(pubman_api)
dois = [
        # '10.1016/j.ijplas.2022.103405',
        # '10.1016/j.matdes.2022.110503',
        '10.1007/s11661-023-06959-4',
        # '10.1016/j.mtla.2022.101625',
        # '10.1016/j.ijrmhm.2023.106124'
        ]

a = doi_parser.download_scopus_pdf(dois[0])
# dois_data = doi_parser.collect_data_for_dois(dois)
# dois_data


# doi_parser.iterate_over_sheets_in_folder(PUBLICATIONS_DOIS_DIR)
# dois_data = doi_parser.collect_data_for_doi('10.1002/advs.202300626')
# doi_parser.compare_author_list_to_pure_db({'Se-Ho Kim': ['MPIE']}, '')
# Out:
# DOI: 10.1007/s11661-023-06959-4
# Initial request status code: 404
# ...

# %% [markdown]
# **Demonstrate full workflow**

# %%
from pubman_manager import DOIParser, PubmanBase, PUBLICATIONS_DOIS_DIR
import os

pubman_api = PubmanBase()
doi_parser = DOIParser(pubman_api)

df_dois_overview = doi_parser.get_dois_for_author('Franz Roters', pubyear_start = 2024)
df_dois_overview
dois_data = doi_parser.collect_data_for_dois(df_dois_overview)
dois_data
from pubman_manager import PUBLICATIONS_DIR
author_name = 'Franz Roters'
doi_parser.write_dois_data(PUBLICATIONS_DIR / 'new' / f'{author_name}_.xlsx', dois_data)
# Out:
# /home/snkrkr/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/snkrkr/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# INFO:root:No auth_token provided, using ENV_USERNAME and ENV_PASSWORD
# INFO:pubman_manager.doi_parser:Scopus not available for 10.26434/chemrxiv-2024-2h7kn, using crossref affiliations...
# INFO:pubman_manager.doi_parser:Scopus not available for 10.26434/chemrxiv-2024-2h7kn-v2, using crossref affiliations...
# df_dois_overview                                DOI  crossref  scopus  \
# 0     10.26434/chemrxiv-2024-2h7kn      True   False
# 1  10.26434/chemrxiv-2024-2h7kn-v2      True   False
#
# ...

# %%
# Out:
# INFO:pubman_manager.doi_parser:Saved /mnt/c/Users/d.mentock/Music/pubman_manager/publications/new/Franz Roters_.xlsx successfully.

# %% [markdown]
# test extract_crossref_authors_affiliations

# %%
from pubman_manager import DOIParser, PubmanBase, PUBLICATIONS_DOIS_DIR

pubman_api = PubmanBase()
doi_parser = DOIParser(pubman_api)

crossref_metadata = doi_parser.get_crossref_metadata('10.1016/j.actamat.2024.120532')
authors = doi_parser.extract_crossref_authors_affiliations(crossref_metadata)
authors
# Out:
# C:\Users\d.mentock\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# INFO:root:No auth_token provided, using ENV_USERNAME and ENV_PASSWORD
# ...

# %% [markdown]
# test process_author_list

# %%
from pubman_manager import DOIParser, PubmanBase, PUBLICATIONS_DOIS_DIR
import logging

pubman_api = PubmanBase()
doi_parser = DOIParser(pubman_api)
author_affiliaton_map = doi_parser.compare_author_list_to_pure_db({('Kilian', 'Schäfer'): []})
author_affiliaton_map
# Out:
# C:\Users\d.mentock\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# INFO:root:No auth_token provided, using ENV_USERNAME and ENV_PASSWORD
# ...

# %%
doi_parser.affiliations_by_name_pubman
# Out:
# {(' Hélène',
#   'Godin'): {'affiliations': {'C-TEC, Parc Economique Centr’alp, Constellium Technology Center, Voreppe, Cedex, France'}},
#  (' Lionel',
#   'Peguet'): {'affiliations': {'C-TEC, Parc Economique Centr’alp, Constellium Technology Center, Voreppe, Cedex, France'}},
#  ('A.',
#   'Abbasi'): {'affiliations': {'Computational Phase Studies, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society',
#    'External Organizations'}, 'identifier': {'id': '/persons/resource/persons125017',
#    'type': 'CONE'}},
#  ('A.',
#   'Abts'): {'affiliations': {'Electrochemistry and Corrosion, Interface Chemistry and Surface Engineering, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society'}, 'identifier': {'id': '/persons/resource/persons125018',
#    'type': 'CONE'}},
#  ('A.',
#   'Al-Ashouri'): {'affiliations': {'Young Investigator Group - Perovskite Tandem Solar Cells, Helmholtz-Zentrum Berlin'}},
#  ('A.',
# ...

# %% [markdown]
# test publication only crossref

# %%
from pubman_manager import DOIParser, PubmanBase, PUBLICATIONS_DOIS_DIR
from unittest.mock import patch

pubman_api = PubmanBase()
doi_parser = DOIParser(pubman_api)
dois = ['10.1016/j.actamat.2024.120532']
with patch.object(DOIParser, 'get_scopus_metadata', return_value=None):
    df_dois_overview = doi_parser.filter_dois(dois)
    dois_data = doi_parser.collect_data_for_dois(df_dois_overview, force=True)
print("dois_data",dois_data)
# Out:
# C:\Users\d.mentock\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# INFO:root:No auth_token provided, using ENV_USERNAME and ENV_PASSWORD
# ...
