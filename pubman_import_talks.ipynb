# %%
from pubman_manager import PubManAPI
import yaml

from dotenv import load_dotenv
import os

load_dotenv()

username = os.getenv("USERNAME")
password = os.getenv("PASSWORD")

api = PubManAPI(username, password)
api.process_excel_and_create_publications('Talks_Tim.xlsx')
# Out:
# C:\Users\d.mentock\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# C:\Users\d.mentock\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# aha Atom Probe Tomography, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society
# aha Atom Probe Tomography, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society
# aha Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society
# aha Atom Probe Tomography, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society
# aha Atom Probe Tomography, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society
# aha Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society
# aha Department of Materials, Imperial College, South Kensington, London SW7 2AZ, UK
# hahaha Index(['Entry Number', 'Event Name', 'Conference start date\n(dd.mm.YYYY)',
#        'Conference end date\n(dd.mm.YYYY)', 'Talk date\n(dd.mm.YYYY)',
#        'Conference Location', 'Invited (y/n)', 'Talk Title',
#        'Comment (Optional)', 'Name 1', 'Helper 1', 'Affiliation 1', 'Name 2',
#        'Helper 2', 'Affiliation 2', 'Name 3', 'Helper 3', 'Affiliation 3',
#        'Name 4', 'Helper 4', 'Affiliation 4', 'Name 5', 'Helper 5',
#        'Affiliation 5', 'Name 6', 'Helper 6', 'Affiliation 6', 'Name 7',
#        'Helper 7', 'Affiliation 7', 'Name 8', 'Helper 8', 'Affiliation 8',
#        'Name 9', 'Helper 9', 'Affiliation 9', 'Name 10', 'Helper 10',
#        'Affiliation 10', 'Name 11', 'Helper 11', 'Affiliation 11', 'Name 12',
#        'Helper 12', 'Affiliation 12', 'Name 13', 'Helper 13', 'Affiliation 13',
#        'Name 14', 'Helper 14', 'Affiliation 14', 'Name 15', 'Helper 15',
#        'Affiliation 15', 'Name 16', 'Helper 16', 'Affiliation 16', 'Name 17',
#        'Helper 17', 'Affiliation 17', 'Name 18', 'Helper 18', 'Affiliation 18',
#        'Name 19', 'Helper 19', 'Affiliation 19', 'Name 20', 'Helper 20',
#        'Affiliation 20', 'Name 21', 'Helper 21', 'Affiliation 21', 'Name 22',
#        'Helper 22', 'Affiliation 22', 'Name 23', 'Helper 23', 'Affiliation 23',
#        'Name 24', 'Helper 24', 'Affiliation 24', 'Name 25', 'Helper 25',
#        'Affiliation 25', 'Name 26', 'Helper 26', 'Affiliation 26', 'Name 27',
#        'Helper 27', 'Affiliation 27', 'Name 28', 'Helper 28', 'Affiliation 28',
#        'Name 29', 'Helper 29', 'Affiliation 29', 'Name 30', 'Helper 30',
#        'Affiliation 30'],
#       dtype='object')
# affiliation Atom Probe Tomography, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society
# self.identifier_paths {'Ab Initio Thermodynamics, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863338', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Adaptive Structural Materials (Experiment), Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863382', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Adaptive Structural Materials (Simulation), Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863339', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Advanced Transmission Electron Microscopy, Structure and Nano-/ Micromechanics of Materials, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863399', 'ou_1863398', 'ou_1863336', 'ou_persistent13'], 'Alloy Design and Thermomechanical Processing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863383', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Alloys for Additive Manufacturing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_2117289', 'ou_3291709', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Alloys for Additive Manufacturing, Project Groups, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_2117289', 'ou_3291709', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Atom Probe Tomography, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863384', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Baumeister, Wolfgang / Molecular Structural Biology, Max Planck Institute of Biochemistry, Max Planck Society': ['ou_1565142', 'ou_1565141', 'ou_persistent13'], 'Biological Composites, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863385', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Bioprocess Engineering, Max Planck Institute for Dynamics of Complex Technical Systems, Max Planck Society': ['ou_1738140', 'ou_1738138', 'ou_persistent13'], 'Central Scientific Facility Thin Film Laboratory, Max Planck Institute for Intelligent Systems, Max Planck Society': ['ou_1497640', 'ou_1497638', 'ou_persistent13'], 'Chemical Physics, Fritz Haber Institute, Max Planck Society': ['ou_24022', 'ou_24021', 'ou_persistent13'], 'Christian Doppler Laboratory for Diffusion and Segregation Mechanisms, Interface Chemistry and Surface Engineering, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863352', 'ou_1863348', 'ou_1863336', 'ou_persistent13'], 'Claudia Felser, Inorganic Chemistry, Max Planck Institute for Chemical Physics of Solids, Max Planck Society': ['ou_1863429', 'ou_1863425', 'ou_1863404', 'ou_persistent13'], 'Combinatorial Metallurgy and Processing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863386', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Complex Concentrated Alloys, Project Groups, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_3291775', 'ou_3291702', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Phase Studies, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863341', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Sustainable Metallurgy, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_3243050', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Computer Center Garching (RZG), Max Planck Institute for Plasma Physics, Max Planck S ...
# affiliation Atom Probe Tomography, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society
# self.identifier_paths {'Ab Initio Thermodynamics, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863338', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Adaptive Structural Materials (Experiment), Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863382', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Adaptive Structural Materials (Simulation), Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863339', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Advanced Transmission Electron Microscopy, Structure and Nano-/ Micromechanics of Materials, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863399', 'ou_1863398', 'ou_1863336', 'ou_persistent13'], 'Alloy Design and Thermomechanical Processing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863383', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Alloys for Additive Manufacturing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_2117289', 'ou_3291709', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Alloys for Additive Manufacturing, Project Groups, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_2117289', 'ou_3291709', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Atom Probe Tomography, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863384', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Baumeister, Wolfgang / Molecular Structural Biology, Max Planck Institute of Biochemistry, Max Planck Society': ['ou_1565142', 'ou_1565141', 'ou_persistent13'], 'Biological Composites, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863385', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Bioprocess Engineering, Max Planck Institute for Dynamics of Complex Technical Systems, Max Planck Society': ['ou_1738140', 'ou_1738138', 'ou_persistent13'], 'Central Scientific Facility Thin Film Laboratory, Max Planck Institute for Intelligent Systems, Max Planck Society': ['ou_1497640', 'ou_1497638', 'ou_persistent13'], 'Chemical Physics, Fritz Haber Institute, Max Planck Society': ['ou_24022', 'ou_24021', 'ou_persistent13'], 'Christian Doppler Laboratory for Diffusion and Segregation Mechanisms, Interface Chemistry and Surface Engineering, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863352', 'ou_1863348', 'ou_1863336', 'ou_persistent13'], 'Claudia Felser, Inorganic Chemistry, Max Planck Institute for Chemical Physics of Solids, Max Planck Society': ['ou_1863429', 'ou_1863425', 'ou_1863404', 'ou_persistent13'], 'Combinatorial Metallurgy and Processing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863386', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Complex Concentrated Alloys, Project Groups, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_3291775', 'ou_3291702', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Phase Studies, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863341', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Sustainable Metallurgy, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_3243050', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Computer Center Garching (RZG), Max Planck Institute for Plasma Physics, Max Planck S ...
# affiliation Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society
# self.identifier_paths {'Ab Initio Thermodynamics, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863338', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Adaptive Structural Materials (Experiment), Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863382', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Adaptive Structural Materials (Simulation), Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863339', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Advanced Transmission Electron Microscopy, Structure and Nano-/ Micromechanics of Materials, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863399', 'ou_1863398', 'ou_1863336', 'ou_persistent13'], 'Alloy Design and Thermomechanical Processing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863383', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Alloys for Additive Manufacturing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_2117289', 'ou_3291709', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Alloys for Additive Manufacturing, Project Groups, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_2117289', 'ou_3291709', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Atom Probe Tomography, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863384', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Baumeister, Wolfgang / Molecular Structural Biology, Max Planck Institute of Biochemistry, Max Planck Society': ['ou_1565142', 'ou_1565141', 'ou_persistent13'], 'Biological Composites, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863385', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Bioprocess Engineering, Max Planck Institute for Dynamics of Complex Technical Systems, Max Planck Society': ['ou_1738140', 'ou_1738138', 'ou_persistent13'], 'Central Scientific Facility Thin Film Laboratory, Max Planck Institute for Intelligent Systems, Max Planck Society': ['ou_1497640', 'ou_1497638', 'ou_persistent13'], 'Chemical Physics, Fritz Haber Institute, Max Planck Society': ['ou_24022', 'ou_24021', 'ou_persistent13'], 'Christian Doppler Laboratory for Diffusion and Segregation Mechanisms, Interface Chemistry and Surface Engineering, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863352', 'ou_1863348', 'ou_1863336', 'ou_persistent13'], 'Claudia Felser, Inorganic Chemistry, Max Planck Institute for Chemical Physics of Solids, Max Planck Society': ['ou_1863429', 'ou_1863425', 'ou_1863404', 'ou_persistent13'], 'Combinatorial Metallurgy and Processing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863386', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Complex Concentrated Alloys, Project Groups, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_3291775', 'ou_3291702', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Phase Studies, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863341', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Sustainable Metallurgy, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_3243050', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Computer Center Garching (RZG), Max Planck Institute for Plasma Physics, Max Planck S ...
# affiliation Atom Probe Tomography, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society
# self.identifier_paths {'Ab Initio Thermodynamics, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863338', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Adaptive Structural Materials (Experiment), Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863382', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Adaptive Structural Materials (Simulation), Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863339', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Advanced Transmission Electron Microscopy, Structure and Nano-/ Micromechanics of Materials, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863399', 'ou_1863398', 'ou_1863336', 'ou_persistent13'], 'Alloy Design and Thermomechanical Processing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863383', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Alloys for Additive Manufacturing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_2117289', 'ou_3291709', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Alloys for Additive Manufacturing, Project Groups, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_2117289', 'ou_3291709', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Atom Probe Tomography, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863384', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Baumeister, Wolfgang / Molecular Structural Biology, Max Planck Institute of Biochemistry, Max Planck Society': ['ou_1565142', 'ou_1565141', 'ou_persistent13'], 'Biological Composites, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863385', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Bioprocess Engineering, Max Planck Institute for Dynamics of Complex Technical Systems, Max Planck Society': ['ou_1738140', 'ou_1738138', 'ou_persistent13'], 'Central Scientific Facility Thin Film Laboratory, Max Planck Institute for Intelligent Systems, Max Planck Society': ['ou_1497640', 'ou_1497638', 'ou_persistent13'], 'Chemical Physics, Fritz Haber Institute, Max Planck Society': ['ou_24022', 'ou_24021', 'ou_persistent13'], 'Christian Doppler Laboratory for Diffusion and Segregation Mechanisms, Interface Chemistry and Surface Engineering, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863352', 'ou_1863348', 'ou_1863336', 'ou_persistent13'], 'Claudia Felser, Inorganic Chemistry, Max Planck Institute for Chemical Physics of Solids, Max Planck Society': ['ou_1863429', 'ou_1863425', 'ou_1863404', 'ou_persistent13'], 'Combinatorial Metallurgy and Processing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863386', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Complex Concentrated Alloys, Project Groups, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_3291775', 'ou_3291702', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Phase Studies, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863341', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Sustainable Metallurgy, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_3243050', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Computer Center Garching (RZG), Max Planck Institute for Plasma Physics, Max Planck S ...
# affiliation Atom Probe Tomography, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society
# self.identifier_paths {'Ab Initio Thermodynamics, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863338', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Adaptive Structural Materials (Experiment), Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863382', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Adaptive Structural Materials (Simulation), Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863339', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Advanced Transmission Electron Microscopy, Structure and Nano-/ Micromechanics of Materials, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863399', 'ou_1863398', 'ou_1863336', 'ou_persistent13'], 'Alloy Design and Thermomechanical Processing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863383', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Alloys for Additive Manufacturing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_2117289', 'ou_3291709', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Alloys for Additive Manufacturing, Project Groups, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_2117289', 'ou_3291709', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Atom Probe Tomography, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863384', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Baumeister, Wolfgang / Molecular Structural Biology, Max Planck Institute of Biochemistry, Max Planck Society': ['ou_1565142', 'ou_1565141', 'ou_persistent13'], 'Biological Composites, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863385', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Bioprocess Engineering, Max Planck Institute for Dynamics of Complex Technical Systems, Max Planck Society': ['ou_1738140', 'ou_1738138', 'ou_persistent13'], 'Central Scientific Facility Thin Film Laboratory, Max Planck Institute for Intelligent Systems, Max Planck Society': ['ou_1497640', 'ou_1497638', 'ou_persistent13'], 'Chemical Physics, Fritz Haber Institute, Max Planck Society': ['ou_24022', 'ou_24021', 'ou_persistent13'], 'Christian Doppler Laboratory for Diffusion and Segregation Mechanisms, Interface Chemistry and Surface Engineering, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863352', 'ou_1863348', 'ou_1863336', 'ou_persistent13'], 'Claudia Felser, Inorganic Chemistry, Max Planck Institute for Chemical Physics of Solids, Max Planck Society': ['ou_1863429', 'ou_1863425', 'ou_1863404', 'ou_persistent13'], 'Combinatorial Metallurgy and Processing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863386', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Complex Concentrated Alloys, Project Groups, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_3291775', 'ou_3291702', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Phase Studies, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863341', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Sustainable Metallurgy, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_3243050', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Computer Center Garching (RZG), Max Planck Institute for Plasma Physics, Max Planck S ...
# affiliation Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society
# self.identifier_paths {'Ab Initio Thermodynamics, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863338', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Adaptive Structural Materials (Experiment), Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863382', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Adaptive Structural Materials (Simulation), Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863339', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Advanced Transmission Electron Microscopy, Structure and Nano-/ Micromechanics of Materials, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863399', 'ou_1863398', 'ou_1863336', 'ou_persistent13'], 'Alloy Design and Thermomechanical Processing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863383', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Alloys for Additive Manufacturing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_2117289', 'ou_3291709', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Alloys for Additive Manufacturing, Project Groups, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_2117289', 'ou_3291709', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Atom Probe Tomography, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863384', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Baumeister, Wolfgang / Molecular Structural Biology, Max Planck Institute of Biochemistry, Max Planck Society': ['ou_1565142', 'ou_1565141', 'ou_persistent13'], 'Biological Composites, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863385', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Bioprocess Engineering, Max Planck Institute for Dynamics of Complex Technical Systems, Max Planck Society': ['ou_1738140', 'ou_1738138', 'ou_persistent13'], 'Central Scientific Facility Thin Film Laboratory, Max Planck Institute for Intelligent Systems, Max Planck Society': ['ou_1497640', 'ou_1497638', 'ou_persistent13'], 'Chemical Physics, Fritz Haber Institute, Max Planck Society': ['ou_24022', 'ou_24021', 'ou_persistent13'], 'Christian Doppler Laboratory for Diffusion and Segregation Mechanisms, Interface Chemistry and Surface Engineering, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863352', 'ou_1863348', 'ou_1863336', 'ou_persistent13'], 'Claudia Felser, Inorganic Chemistry, Max Planck Institute for Chemical Physics of Solids, Max Planck Society': ['ou_1863429', 'ou_1863425', 'ou_1863404', 'ou_persistent13'], 'Combinatorial Metallurgy and Processing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863386', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Complex Concentrated Alloys, Project Groups, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_3291775', 'ou_3291702', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Phase Studies, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863341', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Sustainable Metallurgy, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_3243050', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Computer Center Garching (RZG), Max Planck Institute for Plasma Physics, Max Planck S ...
# affiliation Department of Materials, Imperial College, South Kensington, London SW7 2AZ, UK
# self.identifier_paths {'Ab Initio Thermodynamics, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863338', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Adaptive Structural Materials (Experiment), Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863382', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Adaptive Structural Materials (Simulation), Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863339', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Advanced Transmission Electron Microscopy, Structure and Nano-/ Micromechanics of Materials, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863399', 'ou_1863398', 'ou_1863336', 'ou_persistent13'], 'Alloy Design and Thermomechanical Processing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863383', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Alloys for Additive Manufacturing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_2117289', 'ou_3291709', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Alloys for Additive Manufacturing, Project Groups, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_2117289', 'ou_3291709', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Atom Probe Tomography, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863384', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Baumeister, Wolfgang / Molecular Structural Biology, Max Planck Institute of Biochemistry, Max Planck Society': ['ou_1565142', 'ou_1565141', 'ou_persistent13'], 'Biological Composites, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863385', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Bioprocess Engineering, Max Planck Institute for Dynamics of Complex Technical Systems, Max Planck Society': ['ou_1738140', 'ou_1738138', 'ou_persistent13'], 'Central Scientific Facility Thin Film Laboratory, Max Planck Institute for Intelligent Systems, Max Planck Society': ['ou_1497640', 'ou_1497638', 'ou_persistent13'], 'Chemical Physics, Fritz Haber Institute, Max Planck Society': ['ou_24022', 'ou_24021', 'ou_persistent13'], 'Christian Doppler Laboratory for Diffusion and Segregation Mechanisms, Interface Chemistry and Surface Engineering, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863352', 'ou_1863348', 'ou_1863336', 'ou_persistent13'], 'Claudia Felser, Inorganic Chemistry, Max Planck Institute for Chemical Physics of Solids, Max Planck Society': ['ou_1863429', 'ou_1863425', 'ou_1863404', 'ou_persistent13'], 'Combinatorial Metallurgy and Processing, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863386', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Complex Concentrated Alloys, Project Groups, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_3291775', 'ou_3291702', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Phase Studies, Computational Materials Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_1863341', 'ou_1863337', 'ou_1863336', 'ou_persistent13'], 'Computational Sustainable Metallurgy, Microstructure Physics and Alloy Design, Max-Planck-Institut für Eisenforschung GmbH, Max Planck Society': ['ou_3243050', 'ou_1863381', 'ou_1863336', 'ou_persistent13'], 'Computer Center Garching (RZG), Max Planck Institute for Plasma Physics, Max Planck S ...
