# %%
from pubman_manager import DOIParser, PubmanBase, PUBLICATIONS_DIR
import datetime

import logging
pubman_api = PubmanBase()
doi_parser = DOIParser(pubman_api, logging_level = logging.DEBUG)

dois = ['10.1016/j.carbon.2024.119091', '10.1038/s41467-024-52123-w']

df_dois_overview = doi_parser.filter_dois(dois)
df_dois_overview
# Out:
# crossref_metadata {'indexed': {'date-parts': [[2024, 9, 13]], 'date-time': '2024-09-13T00:47:43Z', 'timestamp': 1726188463421}, 'reference-count': 116, 'publisher': 'Springer Science and Business Media LLC', 'issue': '1', 'license': [{'start': {'date-parts': [[2024, 9, 12]], 'date-time': '2024-09-12T00:00:00Z', 'timestamp': 1726099200000}, 'content-version': 'tdm', 'delay-in-days': 0, 'URL': 'https://creativecommons.org/licenses/by/4.0'}, {'start': {'date-parts': [[2024, 9, 12]], 'date-time': '2024-09-12T00:00:00Z', 'timestamp': 1726099200000}, 'content-version': 'vor', 'delay-in-days': 0, 'URL': 'https://creativecommons.org/licenses/by/4.0'}], 'content-domain': {'domain': ['link.springer.com'], 'crossmark-restriction': False}, 'short-container-title': ['Nat Commun'], 'abstract': '<jats:title>Abstract</jats:title><jats:p>Solid-state Li-ion batteries, based on Ni-rich oxide cathodes and Li-metal anodes, can theoretically reach a high specific energy of 393 Wh kg<jats:sup>−1</jats:sup>
# ...

# %%
dois_data = doi_parser.collect_data_for_dois(df_dois_overview)
pub_path = PUBLICATIONS_DIR / 'new' / f'DOI_list_{datetime.datetime.now().strftime("%d.%m.%Y")}.xlsx'
doi_parser.write_dois_data(pub_path, dois_data)
# Out:
# INFO:root:Saved c:\Users\d.mentock\Music\pubman_manager\publications\new\DOI_list_25.09.2024.xlsx successfully.

# %%
from pubman_manager import DOIParser, PubmanBase, PUBLICATIONS_DIR
import datetime
pub_path = PUBLICATIONS_DIR / 'new' / f'DOI_list_{datetime.datetime.now().strftime("%d.%m.%Y")}.xlsx'
# Out:
# C:\Users\d.mentock\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
from pubman_manager import PubmanCreator
api = PubmanCreator()
api.create_publications(pub_path, overwrite=True,submit_items=False)
# Out:
# C:\Users\d.mentock\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# C:\Users\d.mentock\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# Generating requests for "Unravelling lithium distribution in carbon fibre electrodes for structural batteries with atom probe tomography"
# author Marcus Johansen ['Marcus', 'Johansen']
# author Mahander Pratap Singh ['Mahander', 'Pratap Singh']
# author Johanna Xu ['Johanna', 'Xu']
# author Leif E. Asp ['Leif', 'E. Asp']
# author Baptiste  Gault ['Baptiste', ' Gault']
# author Feng Liu ['Feng', 'Liu']
# ...
